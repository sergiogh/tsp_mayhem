# %%
from qiskit.optimization.applications.ising import tsp
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.axes as axes

import pennylane as qml
from pennylane.operation import Tensor

# %%
nodes = 3
starting_node = 0

# %%
def get_graph(nodes):

    G = nx.Graph()
    G.add_nodes_from(np.arange(0, nodes, 1))

    # Create random positions in the graph. Distance will be calculated from positions
    # Note: Dwave and other solvers require a complete graph
    for i in range(nodes):
        G.nodes[i]['pos'] = (np.random.uniform(0, 10), np.random.uniform(0, 10))

    elist = set()
    for i in range(nodes):
        for t in range(i + 1,nodes):
            y1=G.nodes[i]['pos'][1]
            x1=G.nodes[i]['pos'][0]
            y2=G.nodes[t]['pos'][1]
            x2=G.nodes[t]['pos'][0]
            dist = np.sqrt(((x2-x1)**2)+((y2-y1)**2))
            _tuple = (i, t, dist)
            elist.add(_tuple)

    # tuple is (i,j,weight) where (i,j) is the edge
    G.add_weighted_edges_from(elist)

    return G

def get_cost_matrix(G, nodes):
    w = np.zeros([nodes,nodes])
    for i in range(nodes):
        for j in range(nodes):
            temp = G.get_edge_data(i,j,default=0)
            if temp != 0:
                w[i,j] = temp['weight']
    return w

def calculate_cost(cost_matrix, solution):
    cost = 0
    for i in range(len(solution)):
        a = i % len(solution)
        b = (i + 1) % len(solution)
        cost += cost_matrix[solution[a]][solution[b]]

    return cost

def binary_state_to_points_order(binary_state):
    points_order = []
    number_of_points = int(np.sqrt(len(binary_state)))
    for p in range(number_of_points):
        for j in range(number_of_points):
            if binary_state[(number_of_points) * p + j] == 1:
                points_order.append(j)
    return points_order

G = get_graph(nodes)
cost_matrix = get_cost_matrix(G, nodes)

# %%
coords = []
for node in G.nodes:
    coords.append(G.nodes[node]['pos'])

tsp_instance = tsp.TspData(name = "TSP", dim = len(G.nodes), coord = coords, w = cost_matrix)

qubitOp, offset = tsp.get_operator(tsp_instance)
print("Qubits needed: ", qubitOp.num_qubits)
# Out:
# Qubits needed:  9

# %% [markdown]
# # Now, the actual Pennylane

# %%
dev = qml.device('default.qubit', wires=qubitOp.num_qubits)
qubits = qubitOp.num_qubits

# %%
@qml.qnode(dev)
def circuit(params):
    qml.broadcast(qml.RX, list(range(qubitOp.num_qubits)), 'single', params[0])
    qml.broadcast(qml.RY, list(range(qubitOp.num_qubits)), 'single', params[1])
    qml.broadcast(qml.CNOT, list(range(qubitOp.num_qubits)), pattern="ring")
    return [qml.expval(qml.PauliZ(i)) for i in range(qubitOp.num_qubits)]

# %%
params = [2*np.pi * np.random.random_sample((qubits)), 2*np.pi * np.random.random_sample((qubits))]
params
# Out:
# [array([5.54010667, 4.35130431, 4.55690703, 3.14991399, 6.00725065,
#         4.04630976, 2.66315981, 3.81008093, 0.12059442]),
#  array([1.89485046, 4.14799267, 1.82261136, 3.88310546, 2.6940332 ,
#         0.85120865, 1.87416313, 3.58119515, 3.71256305])]

# %%
res = circuit(params)
res
# Out:
# array([-2.98776830e-04, -4.43103193e-02, -1.70968342e-03, -1.26075836e-03,
#         1.09358543e-03, -4.45359941e-04, -1.18106005e-04, -8.38724243e-05,
#         7.00558057e-05])

# %%
def cost(params):
    exp_values = circuit(params)
    return np.square( np.dot(exp_values, np.ones(qubits) * -1) )

# %%
init_params = params
print(cost(init_params))
# Out:
# 0.002214948094824717

# %%
opt = qml.GradientDescentOptimizer(stepsize=0.2)

# set the number of steps
steps = 40
# set the initial parameter values
params = init_params

for i in range(steps):
    # update the circuit parameters
    params = opt.step(cost, params)
    print(params)
    print("Cost after step {:5d}: {: .7f}".format(i + 1, cost(params)))

print("Ansatz1: Optimized rotation angles: {}".format(params))
# Out:
# [array([5.53929784, 4.3536504 , 4.55723766, 3.14991415, 6.00725181,
#        4.04633074, 2.66315561, 3.81008558, 0.12059494]), array([1.89222953, 4.14939212, 1.82240992, 3.88312345, 2.69403517,
#        0.85122747, 1.87413723, 3.58119792, 3.71256582])]
# Cost after step     1:  0.0021403
# [array([5.53851504, 4.35593359, 4.55755723, 3.14991431, 6.00725291,
#        4.04635102, 2.66315153, 3.8100901 , 0.12059545]), array([1.88967489, 4.15074859, 1.82221548, 3.88314082, 2.69403704,
#        0.85124566, 1.87411212, 3.58120061, 3.71256851])]
# Cost after step     2:  0.0020696
# [array([5.53775694, 4.35815676, 4.55786633, 3.14991446, 6.00725396,
#        4.04637063, 2.66314758, 3.81009448, 0.12059595]), array([1.88718353, 4.15206419, 1.82202765, 3.88315762, 2.69403883,
#        0.85126324, 1.87408777, 3.58120322, 3.71257114])]
# Cost after step     3:  0.0020025
# [array([5.53702231, 4.36032262, 4.55816551, 3.14991461, 6.00725497,
#        4.04638962, 2.66314374, 3.81009875, 0.12059643]), array([1.88475266, 4.15334089, 1.82184608, 3.88317387, 2.69404053,
#        0.85128026, 1.87406413, 3.58120576, 3.7125737 ])]
# Cost after step     4:  0.0019389
# [array([5.53631001, 4.36243367, 4.55845527, 3.14991476, 6.00725593,
#        4.046408  , 2.66314002, 3.81010291, 0.1205969 ]), array([1.88237963, 4.15458052, 1.82167044, 3.88318959, 2.69404215,
#        0.85129675, 1.87404117, 3.58120824, 3.7125762 ])]
# Cost after step     5:  0.0018784
# [array([5.53561897, 4.3644923 , 4.55873608, 3.14991489, 6.00725684,
#        4.04642581, 2.6631364 , 3.81010695, 0.12059736]), array([1.880062  , 4.1557848 , 1.82150042, 3.88320483, 2.69404371,
#        0.85131272, 1.87401886, 3.58121065, 3.71257864])]
# Cost after step     6:  0.0018209
# [array([5.53494818, 4.36650072, 4.55900838, 3.14991503, 6.00725772,
#        4.04644308, 2.66313288, 3.81011089, 0.12059781]), array([1.87779745, 4.15695535, 1.82133574, 3.88321959, 2.69404519,
#        0.85132821, 1.87399717, 3.58121299, 3.71258103])]
# Cost after step     7:  0.0017661
# [array([5.53429671, 4.36846101, 4.55927259, 3.14991516, 6.00725855,
#        4.04645984, 2.66312945, 3.81011473, 0.12059825]), array([1.87558379, 4.15809366, 1.82117614, 3.88323391, 2.69404661,
#        0.85134324, 1.87397606, 3.58121528, 3.71258336])]
# Cost after step     8:  0.0017139
# [array([5.53366368, 4.37037515, 4.55952908, 3.14991528, 6.00725936,
#        4.04647612, 2.66312612, 3.81011848, 0.12059868]), array([1.87341898, 4.15920115, 1.82102137, 3.88324781, 2.69404797,
#        0.85135784, 1.87395551, 3.58121751, 3.71258564])]
# Cost after step     9:  0.0016642
# [array([5.53304827, 4.37224498, 4.55977821, 3.14991541, 6.00726012,
#        4.04649192, 2.66312287, 3.81012213, 0.1205991 ]), array([1.87130109, 4.16027916, 1.8208712 , 3.8832613 , 2.69404927,
#        0.85137201, 1.8739355 , 3.58121969, 3.71258786])]
# Cost after step    10:  0.0016167
# [array([5.5324497 , 4.37407226, 4.56002031, 3.14991553, 6.00726086,
#        4.04650728, 2.66311971, 3.8101257 , 0.12059951]), array([1.86922828, 4.16132893, 1.82072541, 3.88327441, 2.69405051,
#        0.85138579, 1.873916  , 3.58122181, 3.71259004])]
# Cost after step    11:  0.0015713
# [array([5.53186725, 4.37585863, 4.56025571, 3.14991564, 6.00726156,
#        4.04652222, 2.66311662, 3.81012919, 0.12059992]), array([1.86719885, 4.16235164, 1.8205838 , 3.88328716, 2.69405171,
#        0.85139918, 1.87389699, 3.58122389, 3.71259218])]
# Cost after step    12:  0.0015279
# [array([5.53130024, 4.37760565, 4.56048469, 3.14991575, 6.00726224,
#        4.04653676, 2.66311362, 3.81013259, 0.12060031]), array([1.86521116, 4.16334841, 1.82044619, 3.88329955, 2.69405285,
#        0.85141221, 1.87387845, 3.58122591, 3.71259427])]
# Cost after step    13:  0.0014864
# [array([5.53074802, 4.3793148 , 4.56070754, 3.14991586, 6.00726288,
#        4.0465509 , 2.66311068, 3.81013592, 0.1206007 ]), array([1.86326368, 4.16432028, 1.82031239, 3.88331161, 2.69405395,
#        0.8514249 , 1.87386035, 3.58122789, 3.71259632])]
# Cost after step    14:  0.0014467
# [array([5.53020999, 4.38098747, 4.56092451, 3.14991597, 6.00726351,
#        4.04656468, 2.66310782, 3.81013917, 0.12060108]), array([1.86135493, 4.16526824, 1.82018224, 3.88332335, 2.694055  ,
#        0.85143726, 1.87384269, 3.58122983, 3.71259832])]
# Cost after step    15:  0.0014086
# [array([5.52968556, 4.38262499, 4.56113586, 3.14991607, 6.0072641 ,
#        4.0465781 , 2.66310502, 3.81014236, 0.12060145]), array([1.85948354, 4.16619322, 1.82005558, 3.88333478, 2.69405602,
#        0.85144929, 1.87382544, 3.58123173, 3.71260029])]
# Cost after step    16:  0.0013721
# [array([5.5291742 , 4.38422861, 4.56134181, 3.14991618, 6.00726468,
#        4.04659119, 2.66310229, 3.81014547, 0.12060181]), array([1.85764819, 4.16709612, 1.81993227, 3.88334592, 2.69405699,
#        0.85146102, 1.87380858, 3.58123358, 3.71260222])]
# Cost after step    17:  0.0013371
# [array([5.5286754 , 4.38579952, 4.56154258, 3.14991627, 6.00726523,
#        4.04660394, 2.66309961, 3.81014852, 0.12060217]), array([1.85584763, 4.16797777, 1.81981216, 3.88335678, 2.69405792,
#        0.85147246, 1.87379211, 3.5812354 , 3.71260411])]
# Cost after step    18:  0.0013035
# [array([5.52818867, 4.38733886, 4.56173838, 3.14991637, 6.00726576,
#        4.04661639, 2.663097  , 3.81015151, 0.12060252]), array([1.85408069, 4.16883897, 1.81969512, 3.88336736, 2.69405882,
#        0.85148362, 1.873776  , 3.58123718, 3.71260596])]
# Cost after step    19:  0.0012712
# [array([5.52771354, 4.38884771, 4.56192941, 3.14991646, 6.00726627,
#        4.04662853, 2.66309445, 3.81015443, 0.12060286]), array([1.85234623, 4.16968046, 1.81958103, 3.88337769, 2.69405968,
#        0.85149451, 1.87376025, 3.58123892, 3.71260779])]
# Cost after step    20:  0.0012402
# [array([5.5272496 , 4.39032708, 4.56211585, 3.14991656, 6.00726676,
#        4.04664039, 2.66309195, 3.8101573 , 0.1206032 ]), array([1.85064317, 4.17050297, 1.81946977, 3.88338777, 2.69406051,
#        0.85150514, 1.87374483, 3.58124062, 3.71260957])]
# Cost after step    21:  0.0012103
# [array([5.52679641, 4.39177796, 4.56229787, 3.14991664, 6.00726723,
#        4.04665197, 2.6630895 , 3.81016011, 0.12060353]), array([1.8489705 , 4.17130718, 1.81936123, 3.88339761, 2.69406131,
#        0.85151553, 1.87372974, 3.5812423 , 3.71261133])]
# Cost after step    22:  0.0011816
# [array([5.5263536 , 4.39320128, 4.56247565, 3.14991673, 6.00726768,
#        4.04666328, 2.66308711, 3.81016286, 0.12060386]), array([1.84732723, 4.17209372, 1.81925531, 3.88340722, 2.69406208,
#        0.85152567, 1.87371497, 3.58124394, 3.71261306])]
# Cost after step    23:  0.0011539
# [array([5.52592078, 4.39459791, 4.56264934, 3.14991682, 6.00726812,
#        4.04667434, 2.66308476, 3.81016557, 0.12060417]), array([1.84571244, 4.17286323, 1.8191519 , 3.88341661, 2.69406282,
#        0.85153559, 1.8737005 , 3.58124555, 3.71261475])]
# Cost after step    24:  0.0011273
# [array([5.52549761, 4.39596872, 4.56281908, 3.1499169 , 6.00726854,
#        4.04668515, 2.66308246, 3.81016822, 0.12060449]), array([1.84412525, 4.17361627, 1.81905091, 3.88342579, 2.69406353,
#        0.85154528, 1.87368632, 3.58124713, 3.71261642])]
# Cost after step    25:  0.0011016
# [array([5.52508374, 4.3973145 , 4.56298503, 3.14991698, 6.00726894,
#        4.04669572, 2.66308021, 3.81017082, 0.1206048 ]), array([1.84256479, 4.17435342, 1.81895226, 3.88343476, 2.69406422,
#        0.85155476, 1.87367243, 3.58124868, 3.71261805])]
# Cost after step    26:  0.0010768
# [array([5.52467885, 4.39863604, 4.56314731, 3.14991706, 6.00726933,
#        4.04670606, 2.663078  , 3.81017337, 0.1206051 ]), array([1.84103026, 4.1750752 , 1.81885585, 3.88344353, 2.69406488,
#        0.85156403, 1.87365881, 3.5812502 , 3.71261966])]
# Cost after step    27:  0.0010529
# [array([5.52428264, 4.39993406, 4.56330606, 3.14991714, 6.00726971,
#        4.04671618, 2.66307584, 3.81017588, 0.1206054 ]), array([1.83952088, 4.17578212, 1.81876161, 3.88345212, 2.69406552,
#        0.85157311, 1.87364545, 3.58125169, 3.71262125])]
# Cost after step    28:  0.0010299
# [array([5.52389482, 4.40120929, 4.56346139, 3.14991722, 6.00727007,
#        4.04672609, 2.66307371, 3.81017834, 0.12060569]), array([1.83803591, 4.17647466, 1.81866946, 3.88346052, 2.69406613,
#        0.85158199, 1.87363235, 3.58125316, 3.71262281])]
# Cost after step    29:  0.0010076
# [array([5.5235151 , 4.40246238, 4.56361343, 3.14991729, 6.00727042,
#        4.04673579, 2.66307163, 3.81018076, 0.12060598]), array([1.83657464, 4.17715329, 1.81857932, 3.88346874, 2.69406672,
#        0.85159069, 1.87361949, 3.5812546 , 3.71262434])]
# Cost after step    30:  0.0009861
# [array([5.52314323, 4.403694  , 4.56376228, 3.14991736, 6.00727076,
#        4.04674529, 2.66306958, 3.81018314, 0.12060627]), array([1.83513638, 4.17781845, 1.81849113, 3.88347679, 2.69406729,
#        0.85159921, 1.87360687, 3.58125601, 3.71262585])]
# Cost after step    31:  0.0009652
# [array([5.52277894, 4.40490476, 4.56390806, 3.14991744, 6.00727108,
#        4.0467546 , 2.66306758, 3.81018548, 0.12060655]), array([1.83372049, 4.17847056, 1.81840482, 3.88348467, 2.69406784,
#        0.85160756, 1.87359449, 3.5812574 , 3.71262733])]
# Cost after step    32:  0.0009451
# [array([5.522422  , 4.40609525, 4.56405086, 3.14991751, 6.00727139,
#        4.04676373, 2.66306561, 3.81018778, 0.12060682]), array([1.83232633, 4.17911003, 1.81832032, 3.8834924 , 2.69406837,
#        0.85161574, 1.87358233, 3.58125877, 3.7126288 ])]
# Cost after step    33:  0.0009257
# [array([5.52207217, 4.40726606, 4.56419077, 3.14991757, 6.0072717 ,
#        4.04677267, 2.66306367, 3.81019004, 0.1206071 ]), array([1.8309533 , 4.17973724, 1.81823758, 3.88349997, 2.69406889,
#        0.85162376, 1.87357038, 3.58126012, 3.71263024])]
# Cost after step    34:  0.0009068
# [array([5.52172923, 4.40841773, 4.5643279 , 3.14991764, 6.00727199,
#        4.04678144, 2.66306177, 3.81019226, 0.12060736]), array([1.82960083, 4.18035257, 1.81815654, 3.88350739, 2.69406938,
#        0.85163163, 1.87355865, 3.58126144, 3.71263165])]
# Cost after step    35:  0.0008886
# [array([5.52139297, 4.40955078, 4.56446233, 3.14991771, 6.00727227,
#        4.04679004, 2.6630599 , 3.81019445, 0.12060763]), array([1.82826836, 4.18095637, 1.81807715, 3.88351466, 2.69406986,
#        0.85163934, 1.87354712, 3.58126274, 3.71263305])]
# Cost after step    36:  0.0008709
# [array([5.52106318, 4.41066573, 4.56459414, 3.14991777, 6.00727254,
#        4.04679848, 2.66305807, 3.8101966 , 0.12060789]), array([1.82695536, 4.18154899, 1.81799934, 3.88352179, 2.69407032,
#        0.8516469 , 1.87353579, 3.58126402, 3.71263443])]
# Cost after step    37:  0.0008538
# [array([5.52073967, 4.41176305, 4.56472342, 3.14991784, 6.0072728 ,
#        4.04680676, 2.66305626, 3.81019871, 0.12060814]), array([1.82566131, 4.18213074, 1.81792307, 3.88352879, 2.69407076,
#        0.85165433, 1.87352465, 3.58126528, 3.71263579])]
# Cost after step    38:  0.0008372
# [array([5.52042226, 4.41284322, 4.56485024, 3.1499179 , 6.00727305,
#        4.04681488, 2.66305449, 3.8102008 , 0.1206084 ]), array([1.82438571, 4.18270194, 1.8178483 , 3.88353566, 2.69407119,
#        0.85166161, 1.87351369, 3.58126653, 3.71263712])]
# Cost after step    39:  0.0008211
# [array([5.52011075, 4.41390669, 4.56497468, 3.14991796, 6.0072733 ,
#        4.04682286, 2.66305274, 3.81020285, 0.12060864]), array([1.8231281 , 4.1832629 , 1.81777497, 3.8835424 , 2.6940716 ,
#        0.85166877, 1.87350292, 3.58126775, 3.71263844])]
# Cost after step    40:  0.0008055
# Ansatz1: Optimized rotation angles: [array([5.52011075, 4.41390669, 4.56497468, 3.14991796, 6.0072733 ,
#        4.04682286, 2.66305274, 3.81020285, 0.12060864]), array([1.8231281 , 4.1832629 , 1.81777497, 3.8835424 , 2.6940716 ,
#        0.85166877, 1.87350292, 3.58126775, 3.71263844])]

# %%
print(params)
print(circuit(params))
print(cost(params))
# Out:
# [array([5.52011075, 4.41390669, 4.56497468, 3.14991796, 6.0072733 ,
#        4.04682286, 2.66305274, 3.81020285, 0.12060864]), array([1.8231281 , 4.1832629 , 1.81777497, 3.8835424 , 2.6940716 ,
#        0.85166877, 1.87350292, 3.58126775, 3.71263844])]
# [-2.17563811e-04 -2.67838004e-02 -9.61773728e-04 -7.08949307e-04
#   6.14959951e-04 -2.50145931e-04 -6.61931616e-05 -4.70006311e-05
#   3.92560722e-05]
# 0.0008054931350155965

# %%
@qml.qnode(dev)
def final_circ(params):
    qml.broadcast(qml.RX, list(range(qubitOp.num_qubits)), 'single', params[0])
    qml.broadcast(qml.RY, list(range(qubitOp.num_qubits)), 'single', params[1])
    qml.broadcast(qml.CNOT, list(range(qubitOp.num_qubits)), pattern="ring")
    return qml.probs(wires=range(qubitOp.num_qubits))

# %%
result = final_circ(params)
print("Different states: ", len(result))
print(min(result))
i, = np.where(np.isclose(result, min(result))) 
print(i)
print("Cost: ", cost(params))
# Out:
# Different states:  512
# 9.54566212706742e-07
# [443]
# Cost:  0.0008054931350155965

# %%
binary_result = list(map(int, bin(i[0])[2:]))
print(binary_result)
path_result = binary_state_to_points_order(list(binary_result))
path_result
# Out:
# [1, 1, 0, 1, 1, 1, 0, 1, 1]
# [0, 1, 0, 1, 2, 1, 2]

# %% [markdown]
# ## Pennylane VQE

# %%
dev = qml.device('default.qubit', wires=qubitOp.num_qubits)

def circuit(params, wires):
    #qml.BasisState(np.array([1, 1, 0, 0]), wires=wires)
    for i in wires:
        qml.Rot(*params[i], wires=i)
    qml.CNOT(wires=[2, 3])
    qml.CNOT(wires=[2, 0])
    qml.CNOT(wires=[3, 1])

# %%
qubitOp.to_dict()['paulis']
# Out:
# [{'label': 'IIIIIIIIZ', 'coeff': {'real': -100002.44122189419, 'imag': 0.0}},
#  {'label': 'IIIIZIIII', 'coeff': {'real': -100001.73958282053, 'imag': 0.0}},
#  {'label': 'IIIIZIIIZ', 'coeff': {'real': 0.3781811300550017, 'imag': 0.0}},
#  {'label': 'IIIIIIIZI', 'coeff': {'real': -100002.44122189419, 'imag': 0.0}},
#  {'label': 'IIIZIIIII', 'coeff': {'real': -100001.73958282053, 'imag': 0.0}},
#  {'label': 'IIIZIIIZI', 'coeff': {'real': 0.3781811300550017, 'imag': 0.0}},
#  {'label': 'IIIIIIZII', 'coeff': {'real': -100002.44122189419, 'imag': 0.0}},
#  {'label': 'IIIIIZIII', 'coeff': {'real': -100001.73958282053, 'imag': 0.0}},
#  {'label': 'IIIIIZZII', 'coeff': {'real': 0.3781811300550017, 'imag': 0.0}},
#  {'label': 'IZIIIIIII', 'coeff': {'real': -100002.66808019449, 'imag': 0.0}},
#  {'label': 'IZIIIIIIZ', 'coeff': {'real': 0.8424298170353066, 'imag': 0.0}},
#  {'label': 'ZIIIIIIII', 'coeff': {'real': -100002.66808019449, 'imag': 0.0}},
#  {'label': 'ZIIIIIIZI', 'coeff': {'real': 0.8424298170353066, 'imag': 0.0}},
#  {'label': 'IIZIIIIII', 'coeff': {'real': -100002.66808019449, 'imag': 0.0}},
#  {'label': 'IIZIIIZII', 'coeff': {'real': 0.8424298170353066, 'imag': 0.0}},
#  {'label': 'IIIIIZIZI', 'coeff': {'real': 0.3781811300550017, 'imag': 0.0}},
#  {'label': 'IIIIZIZII', 'coeff': {'real': 0.3781811300550017, 'imag': 0.0}},
#  {'label': 'IIIZIIIIZ', 'coeff': {'real': 0.3781811300550017, 'imag': 0.0}},
#  {'label': 'IZIIIZIII', 'coeff': {'real': 0.49161028021195696, 'imag': 0.0}},
#  {'label': 'ZIIIZIIII', 'coeff': {'real': 0.49161028021195696, 'imag': 0.0}},
#  {'label': 'IIZZIIIII', 'coeff': {'real': 0.49161028021195696, 'imag': 0.0}},
#  {'label': 'IIZIIIIZI', 'coeff': {'real': 0.8424298170353066, 'imag': 0.0}},
#  {'label': 'IZIIIIZII', 'coeff': {'real': 0.8424298170353066, 'imag': 0.0}},
#  {'label': 'ZIIIIIIIZ', 'coeff': {'real': 0.8424298170353066, 'imag': 0.0}},
#  {'label': 'IIZIZIIII', 'coeff': {'real': 0.49161028021195696, 'imag': 0.0}},
#  {'label': 'IZIZIIIII', 'coeff': {'real': 0.49161028021195696, 'imag': 0.0}},
#  {'label': 'ZIIIIZIII', 'coeff': {'real': 0.49161028021195696, 'imag': 0.0}},
#  {'label': 'IIIIIZIIZ', 'coeff': {'real': 50000.0, 'imag': 0.0}},
#  {'label': 'IIZIIIIIZ', 'coeff': {'real': 50000.0, 'imag': 0.0}},
#  {'label': 'IIZIIZIII', 'coeff': {'real': 50000.0, 'imag': 0.0}},
#  {'label': 'IIIIZIIZI', 'coeff': {'real': 50000.0, 'imag': 0.0}},
#  {'label': 'IZIIIIIZI', 'coeff': {'real': 50000.0, 'imag': 0.0}},
#  {'label': 'IZIIZIIII', 'coeff': {'real': 50000.0, 'imag': 0.0}},
#  {'label': 'IIIZIIZII', 'coeff': {'real': 50000.0, 'imag': 0.0}},
#  {'label': 'ZIIIIIZII', 'coeff': {'real': 50000.0, 'imag': 0.0}},
#  {'label': 'ZIIZIIIII', 'coeff': {'real': 50000.0, 'imag': 0.0}},
#  {'label': 'IIIIIIIZZ', 'coeff': {'real': 50000.0, 'imag': 0.0}},
#  {'label': 'IIIIIIZIZ', 'coeff': {'real': 50000.0, 'imag': 0.0}},
#  {'label': 'IIIIIIZZI', 'coeff': {'real': 50000.0, 'imag': 0.0}},
#  {'label': 'IIIIZZIII', 'coeff': {'real': 50000.0, 'imag': 0.0}},
#  {'label': 'IIIZIZIII', 'coeff': {'real': 50000.0, 'imag': 0.0}},
#  {'label': 'IIIZZIIII', 'coeff': {'real': 50000.0, 'imag': 0.0}},
#  {'label': 'IZZIIIIII', 'coeff': {'real': 50000.0, 'imag': 0.0}},
#  {'label': 'ZIZIIIIII', 'coeff': {'real': 50000.0, 'imag': 0.0}},
#  {'label': 'ZZIIIIIII', 'coeff': {'real': 50000.0, 'imag': 0.0}}]

# %%
coeffs = []
obs = []
for i in qubitOp.to_dict()['paulis']:
    obs.append(i['label'])
    coeffs.append(i['coeff']['real'])

final_obs = []
for idx, observable in enumerate(obs):
    for sidx, s in enumerate(observable):
        if(sidx == 0): T = Tensor()
        if (s == 'I'):
            T = Tensor(T, qml.Identity(sidx))
        elif (s == 'Z'):
            T = Tensor(T, qml.PauliZ(sidx))
    final_obs.append(T)

H = qml.Hamiltonian(coeffs, final_obs)
print(H)
# Out:
# (-100002.44122189419) [I0 I1 I2 I3 I4 I5 I6 I7 Z8]
# + (-100001.73958282053) [I0 I1 I2 I3 Z4 I5 I6 I7 I8]
# + (0.3781811300550017) [I0 I1 I2 I3 Z4 I5 I6 I7 Z8]
# + (-100002.44122189419) [I0 I1 I2 I3 I4 I5 I6 Z7 I8]
# + (-100001.73958282053) [I0 I1 I2 Z3 I4 I5 I6 I7 I8]
# + (0.3781811300550017) [I0 I1 I2 Z3 I4 I5 I6 Z7 I8]
# + (-100002.44122189419) [I0 I1 I2 I3 I4 I5 Z6 I7 I8]
# + (-100001.73958282053) [I0 I1 I2 I3 I4 Z5 I6 I7 I8]
# + (0.3781811300550017) [I0 I1 I2 I3 I4 Z5 Z6 I7 I8]
# + (-100002.66808019449) [I0 Z1 I2 I3 I4 I5 I6 I7 I8]
# + (0.8424298170353066) [I0 Z1 I2 I3 I4 I5 I6 I7 Z8]
# + (-100002.66808019449) [Z0 I1 I2 I3 I4 I5 I6 I7 I8]
# + (0.8424298170353066) [Z0 I1 I2 I3 I4 I5 I6 Z7 I8]
# + (-100002.66808019449) [I0 I1 Z2 I3 I4 I5 I6 I7 I8]
# + (0.8424298170353066) [I0 I1 Z2 I3 I4 I5 Z6 I7 I8]
# + (0.3781811300550017) [I0 I1 I2 I3 I4 Z5 I6 Z7 I8]
# + (0.3781811300550017) [I0 I1 I2 I3 Z4 I5 Z6 I7 I8]
# + (0.3781811300550017) [I0 I1 I2 Z3 I4 I5 I6 I7 Z8]
# + (0.49161028021195696) [I0 Z1 I2 I3 I4 Z5 I6 I7 I8]
# + (0.49161028021195696) [Z0 I1 I2 I3 Z4 I5 I6 I7 I8]
# + (0.49161028021195696) [I0 I1 Z2 Z3 I4 I5 I6 I7 I8]
# + (0.8424298170353066) [I0 I1 Z2 I3 I4 I5 I6 Z7 I8]
# + (0.8424298170353066) [I0 Z1 I2 I3 I4 I5 Z6 I7 I8]
# + (0.8424298170353066) [Z0 I1 I2 I3 I4 I5 I6 I7 Z8]
# + (0.49161028021195696) [I0 I1 Z2 I3 Z4 I5 I6 I7 I8]
# + (0.49161028021195696) [I0 Z1 I2 Z3 I4 I5 I6 I7 I8]
# + (0.49161028021195696) [Z0 I1 I2 I3 I4 Z5 I6 I7 I8]
# + (50000.0) [I0 I1 I2 I3 I4 Z5 I6 I7 Z8]
# + (50000.0) [I0 I1 Z2 I3 I4 I5 I6 I7 Z8]
# + (50000.0) [I0 I1 Z2 I3 I4 Z5 I6 I7 I8]
# + (50000.0) [I0 I1 I2 I3 Z4 I5 I6 Z7 I8]
# + (50000.0) [I0 Z1 I2 I3 I4 I5 I6 Z7 I8]
# + (50000.0) [I0 Z1 I2 I3 Z4 I5 I6 I7 I8]
# + (50000.0) [I0 I1 I2 Z3 I4 I5 Z6 I7 I8]
# + (50000.0) [Z0 I1 I2 I3 I4 I5 Z6 I7 I8]
# + (50000.0) [Z0 I1 I2 Z3 I4 I5 I6 I7 I8]
# + (50000.0) [I0 I1 I2 I3 I4 I5 I6 Z7 Z8]
# + (50000.0) [I0 I1 I2 I3 I4 I5 Z6 I7 Z8]
# + (50000.0) [I0 I1 I2 I3 I4 I5 Z6 Z7 I8]
# + (50000.0) [I0 I1 I2 I3 Z4 Z5 I6 I7 I8]
# + (50000.0) [I0 I1 I2 Z3 I4 Z5 I6 I7 I8]
# + (50000.0) [I0 I1 I2 Z3 Z4 I5 I6 I7 I8]
# + (50000.0) [I0 Z1 Z2 I3 I4 I5 I6 I7 I8]
# + (50000.0) [Z0 I1 Z2 I3 I4 I5 I6 I7 I8]
# + (50000.0) [Z0 Z1 I2 I3 I4 I5 I6 I7 I8]

# %%
cost_fn = qml.VQECost(circuit, H, dev)

# %%
opt = qml.GradientDescentOptimizer(stepsize=0.4)
np.random.seed(0)
params = np.random.normal(0, np.pi, (qubitOp.num_qubits, 3))
print(params)
# Out:
# [[ 5.54193389  1.25713095  3.07479606]
#  [ 7.03997361  5.86710646 -3.07020901]
#  [ 2.98479079 -0.47550269 -0.32427159]
#  [ 1.28993324  0.45252622  4.56873497]
#  [ 2.39087053  0.38225334  1.39443747]
#  [ 1.04826882  4.69378784 -0.64452369]
#  [ 0.98353119 -2.6832209  -8.02045405]
#  [ 2.05340338  2.71570641 -2.33158018]
#  [ 7.13064445 -4.56902452  0.14375462]]

# %%
max_iterations = 100
conv_tol = 1e-06

prev_energy = cost_fn(params)
for n in range(max_iterations):
    params = opt.step(cost_fn, params)
    energy = cost_fn(params)
    conv = np.abs(energy - prev_energy)

    if n % 5 == 0:
        print('Iteration = {:},  Cost = {:.8f},  Convergente = {'
              ':.8f} Ha'.format(n, energy, conv))
        print("Parameters:")
        print(params)

    if conv <= conv_tol:
        break

    prev_energy = energy

print("===================")
print('Final convergence parameter = {:.8f} Ha'.format(conv))
print('Cost: ',energy)
print('Final circuit parameters = \n', params)
# Out:
# Iteration = 0,  Cost = -44405.94955675,  Convergente = 45382.12094243 Ha
# Parameters:
# [[ 5.54193389e+00  2.78811379e+03  3.07479606e+00]
#  [ 7.03997361e+00  3.30916058e+03 -3.07020901e+00]
#  [ 2.98479079e+00  5.92741829e+04 -3.24271587e-01]
#  [ 1.28993324e+00 -1.63886430e+04  4.56873497e+00]
#  [ 2.39087053e+00 -1.04318295e+04  1.39443747e+00]
#  [ 1.04826882e+00 -9.46469189e+03 -6.44523694e-01]
#  [ 9.83531192e-01  1.75169344e+04 -8.02045405e+00]
#  [ 2.05340338e+00 -1.14036618e+04 -2.33158018e+00]
#  [ 7.13064445e+00 -5.81420151e+04  1.43754622e-01]]
# Iteration = 5,  Cost = 429019.83323319,  Convergente = 185741.61887101 Ha
# Parameters:
# [[ 5.54193389e+00 -5.72654989e+04  3.07479606e+00]
#  [ 7.03997361e+00  1.93283648e+04 -3.07020901e+00]
#  [ 2.98479079e+00  6.73673059e+04 -3.24271587e-01]
#  [ 1.28993324e+00 -7.57828500e+02  4.56873497e+00]
#  [ 2.39087053e+00  1.10693876e+05  1.39443747e+00]
#  [ 1.04826882e+00  6.30556742e+04 -6.44523694e-01]
#  [ 9.83531192e-01  6.84070600e+04 -8.02045405e+00]
#  [ 2.05340338e+00  1.96937677e+05 -2.33158018e+00]
#  [ 7.13064445e+00  5.10174366e+04  1.43754622e-01]]
# Iteration = 10,  Cost = -200407.36477562,  Convergente = 249759.62891750 Ha
# Parameters:
# [[ 5.54193389e+00 -4.12170503e+04  3.07479606e+00]
#  [ 7.03997361e+00 -2.46230685e+04 -3.07020901e+00]
#  [ 2.98479079e+00  6.14280932e+04 -3.24271587e-01]
#  [ 1.28993324e+00 -1.99137258e+04  4.56873497e+00]
#  [ 2.39087053e+00  1.19314499e+05  1.39443747e+00]
#  [ 1.04826882e+00  1
+05 -3.24271587e-01]
#  [ 1.28993324e+00 -4.61054445e+05  4.56873497e+00]
#  [ 2.39087053e+00  7.50730494e+05  1.39443747e+00]
#  [ 1.04826882e+00  7.94885768e+04 -6.44523694e-01]
#  [ 9.83531192e-01  5.18720764e+04 -8.02045405e+00]
#  [ 2.05340338e+00  3.00777486e+05 -2.33158018e+00]
#  [ 7.13064445e+00  6.35029444e+05  1.43754622e-01]]
# Iteration = 95,  Cost = 99964.72743591,  Convergente = 190294.22903043 Ha
# Parameters:
# [[ 5.54193389e+00 -9.47973652e+04  3.07479606e+00]
#  [ 7.03997361e+00  6.14140134e+04 -3.07020901e+00]
#  [ 2.98479079e+00 -6.44387617e+05 -3.24271587e-01]
#  [ 1.28993324e+00 -5.22453372e+05  4.56873497e+00]
#  [ 2.39087053e+00  8.10087522e+05  1.39443747e+00]
#  [ 1.04826882e+00  8.56195861e+04 -6.44523694e-01]
#  [ 9.83531192e-01  1.92124325e+05 -8.02045405e+00]
#  [ 2.05340338e+00  2.63510076e+05 -2.33158018e+00]
#  [ 7.13064445e+00  6.82702641e+05  1.43754622e-01]]
# ===================
# Final convergence parameter = 85843.02796139 Ha
# Cost:  118467.22984988677
# Final circuit parameters =
#  [[ 5.54193389e+00 -1.00911681e+05  3.07479606e+00]
#  [ 7.03997361e+00  6.98537237e+04 -3.07020901e+00]
#  [ 2.98479079e+00 -6.31148400e+05 -3.24271587e-01]
#  [ 1.28993324e+00 -5.30984208e+05  4.56873497e+00]
#  [ 2.39087053e+00  8.37048682e+05  1.39443747e+00]
#  [ 1.04826882e+00  2.60560554e+05 -6.44523694e-01]
#  [ 9.83531192e-01  1.66561079e+05 -8.02045405e+00]
#  [ 2.05340338e+00  3.14222777e+05 -2.33158018e+00]
#  [ 7.13064445e+00  7.03146709e+05  1.43754622e-01]]

# %%
@qml.qnode(dev)
def final_circ(params):
    circuit(params, range(qubitOp.num_qubits))
    return qml.probs(wires=range(qubitOp.num_qubits))

# %%
result = final_circ(params)
print(result)
# Out:
# [1.83762197e-13 2.50242801e-13 2.29756743e-14 3.12877033e-14
#  6.62150892e-16 9.01700659e-16 8.27883180e-17 1.12739078e-16
#  3.34702449e-06 4.55789493e-06 4.18476410e-07 5.69870794e-07
#  1.20603437e-08 1.64234769e-08 1.50789734e-09 2.05341719e-09
#  4.34279848e-12 5.91391524e-12 5.42977417e-13 7.39413177e-13
#  1.56484192e-14 2.13096290e-14 1.95651220e-15 2.66432978e-15
#  7.90992549e-05 1.07715403e-04 9.88973110e-06 1.34675905e-05
#  2.85018590e-07 3.88131245e-07 3.56356986e-08 4.85278104e-08
#  3.66700129e-12 4.99363138e-12 4.58482911e-13 6.24350655e-13
#  1.32133171e-14 1.79935674e-14 1.65205289e-15 2.24972464e-15
#  6.67903591e-05 9.09534541e-05 8.35075743e-06 1.13718543e-05
#  2.40665907e-07 3.27732862e-07 3.00903100e-08 4.09762378e-08
#  8.66611732e-11 1.18013036e-10 1.08351931e-11 1.47550972e-11
#  3.12266473e-13 4.25236737e-13 3.90424847e-14 5.31670871e-14
#  1.57843710e-03 2.14947649e-03 1.97351018e-04 2.68747721e-04
